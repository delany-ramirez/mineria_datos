# %% [markdown]
# # Taller alternativo – Base de datos **Sakila**
#
# **Curso:** Machine Learning
# **Duración estimada:** 2 horas
#
# **Objetivo:** reforzar los fundamentos de SQL desde consultas básicas hasta `JOIN` y `GROUP BY`. Resuelve cada ítem con un **único** bloque de código SQL y presenta la salida obtenida.

# %% [markdown]
# > **Instrucciones:**
# >
# > 1. Conéctate a tu instancia de MySQL que contenga la base de datos **sakila**.
# > 2. Para cada ejercicio, escribe la sentencia SQL dentro de la celda de código correspondiente.
# > 3. Incluye un breve comentario que explique qué hace tu consulta.
# > 4. Guarda y entrega el notebook con tus resultados.

# %% [markdown]
# ## A. Consultas `SELECT` básicas

# %%
# !pip install sqlalchemy psycopg2-binary

# %%
from sqlalchemy import create_engine, text
import pandas as pd

def connect_to_db():
    user = 'readonly_user.xcqqjphjmicrxdynthas'
    password = 'UTP123'
    host = 'aws-1-us-west-2.pooler.supabase.com'
    port = '6543'
    database = 'postgres'
    url = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}'
    return create_engine(url)

# %%
def query_to_dataframe(engine, query):
    with engine.connect() as connection:
        result = connection.execute(text(query))
        return pd.DataFrame(result.fetchall(), columns=result.keys())

engine = connect_to_db()

# %%
# Test query
engine = connect_to_db()
test_query = "select * from actor limit 5;"
df_tables = query_to_dataframe(engine, test_query)
df_tables
# Out:
#    actor_id first_name     last_name               last_update
# 0         1   PENELOPE       GUINESS 2022-02-15 09:34:33+00:00
# 1         2       NICK      WAHLBERG 2022-02-15 09:34:33+00:00
# 2         3         ED         CHASE 2022-02-15 09:34:33+00:00
# 3         4   JENNIFER         DAVIS 2022-02-15 09:34:33+00:00
# 4         5     JOHNNY  LOLLOBRIGIDA 2022-02-15 09:34:33+00:00

# %% [markdown]
# **1. Listar los **títulos** de todas las películas ordenados alfabéticamente.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **2. Mostrar los **nombres y apellidos** de los actores cuyo apellido comience por “M”.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **3. Obtener los **títulos distintos** de las películas cuya duración (*length*) sea mayor a 180 min.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **4. ¿Cuántos clientes viven en **‘California’**? Muestra solo el conteo.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **5. Traer los **10 clientes** más recientes (*create_date*), mostrando nombre, email y fecha de creación.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# ## B. Agregación y `GROUP BY`, `JOIN` y subconsultas

# %% [markdown]
# **6. Calcular la **duración promedio** de las películas por categoría (*category*).**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **7. Listar las **5 categorías** con mayor número de películas (muestra categoría y total).**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **8. Obtener la cantidad de **películas alquiladas** por cada cliente y ordenar de mayor a menor.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **9. Mostrar, por país, la **facturación total** (*amount*) registrada en la tabla *payment*.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **10. De los países anteriores, filtra solo los que superen **USD 20 000** de facturación (usa `HAVING`).**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **11. Listar las películas junto con el **nombre de su categoría principal**.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **12. Mostrar el **inventario disponible** por tienda (*store*): ID de tienda, ciudad y número de películas.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **13. Para cada cliente, desplegar su **último alquiler** (fecha y título); utiliza una subconsulta o *window function*.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **14. Obtener los **cinco actores** que más veces han aparecido en películas, con su conteo de participaciones.**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# **15. Identificar las películas que **nunca han sido alquiladas** (título y fecha de lanzamiento).**

# %%
-- Escribe tu consulta SQL aquí

# %% [markdown]
# ### Recomendaciones de entrega
# - Ejecuta cada consulta y deja los resultados visibles en la salida de la celda.
# - Asegúrate de que cada celda de código contenga **solo una** sentencia SQL.
# - Comenta tu código de ser necesario para mejorar la comprensión.
